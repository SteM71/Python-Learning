# %%
import pandas as pd
child_identifiers = pd.read_csv(r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv")
child_identifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.5+ KB

# %%
child_info.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 child_info.info()
#
# NameError: name 'child_info' is not defined

# %%
child_info['Birthday'] = pd.to_datetime(child_info['Birthday'], format="%d/%m/%Y", errors="coerce")

# %%
child_identifiers['PersonBirthDate']=pd.to_datetime(child_identifiers['PersonBirthDate'])
child_identifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    datetime64[ns]
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 23.5+ KB

# %%
child_identifiers['Age'] =pd.to_datetime(child_identifiers['PersonBirthDate'], format="%d/%m/%Y", errors="coerce")
child_identifiers
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0             0  RND000215205141  A850728973744        NaN         NaN
# 1             1  RND000824303014  A141396438491        NaN         NaN
# 2             2  RND000750143123  A929946861554        NaN         NaN
# 3             3  RND000909164501  A612330267292        NaN         NaN
# 4             4  RND000382171815  A604459366806        NaN         NaN
# ..          ...              ...            ...        ...         ...
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate  \
# 0        2019-12-06                     NaN              1             NaN
# 1        2011-04-27                     NaN              9             NaN
# 2        2017-06-06              2019-12-06              1             NaN
# 3        2014-10-03                     NaN              0             NaN
# 4        2019-09-25                     NaN              2             NaN
# ..              ...                     ...            ...             ...
# 327      2010-07-07                     NaN              2             NaN
# 328      2018-08-14                     NaN              2             NaN
# 329      2021-12-09                     NaN             51             NaN
# 330      2013-07-23                     NaN              2             NaN
# 331      2021-10-25                     NaN              9             NaN
#
#            Age
# 0   2019-12-06
# 1   2011-04-27
# 2   2017-06-06
# 3   2014-10-03
# 4   2019-09-25
# ..         ...
# 327 2010-07-07
# 328 2018-08-14
# 329 2021-12-09
# 330 2013-07-23
# 331 2021-10-25
#
# [332 rows x 10 columns]

# %%
child_characteristics=pd.read_csv(r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildCharacteristics.csv")
child_characteristics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  332 non-null    int64
#  1   LAchildID   332 non-null    object
#  2   Ethnicity   332 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 7.9+ KB

# %%
df=pd.merge(child_identifiers, child_characteristics, how='left', on='LAchildID')
df
# Out:
#      Unnamed: 0_x        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0               0  RND000215205141  A850728973744        NaN         NaN
# 1               1  RND000824303014  A141396438491        NaN         NaN
# 2               2  RND000750143123  A929946861554        NaN         NaN
# 3               3  RND000909164501  A612330267292        NaN         NaN
# 4               4  RND000382171815  A604459366806        NaN         NaN
# ..            ...              ...            ...        ...         ...
# 327           327  RND000112711501  A465246916125        NaN         NaN
# 328           328  RND000513120794  A540014111973        NaN         NaN
# 329           329  RND000541643134  A549582689058        NaN         NaN
# 330           330  RND000404939452  A889492349196        NaN         NaN
# 331           331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate  \
# 0        2019-12-06                     NaN              1             NaN
# 1        2011-04-27                     NaN              9             NaN
# 2        2017-06-06              2019-12-06              1             NaN
# 3        2014-10-03                     NaN              0             NaN
# 4        2019-09-25                     NaN              2             NaN
# ..              ...                     ...            ...             ...
# 327      2010-07-07                     NaN              2             NaN
# 328      2018-08-14                     NaN              2             NaN
# 329      2021-12-09                     NaN             51             NaN
# 330      2013-07-23                     NaN              2             NaN
# 331      2021-10-25                     NaN              9             NaN
#
#      Unnamed: 0_y Ethnicity
# 0               0      WIRT
# 1               1      WROM
# 2               2      AOTH
# 3               3      MWBC
# 4               4      APKN
# ..            ...       ...
# 327           327      WOTH
# 328           328      WROM
# 329           329      BCRB
# 330           330      AIND
# 331           331      WBRI
#
# [332 rows x 11 columns]

# %%
child_info = pd.DataFrame({'ChildId':['id1', 'id2', 'id3', 'id4', 'id5'],
                   'Age first contact':[6,12,11,1,19],
                   'Gender':['M','m', 'F', '', 'F' ],
                   'Birthday':['01/01/2002', '02/02/2003', pd.NA, '03/03/2023', '06/01/2012'],
                   'CP Plan?':['Y', 'n', 'N', 'No', 'yES'],})

# %%
condition=child_info['Age first contact']< child_info['Age first contact'].mean()
over_mean=child_info[condition]
over_mean
# Out:
#   ChildId  Age first contact Gender    Birthday CP Plan?
# 0     id1                  6      M  01/01/2002        Y
# 3     id4                  1         03/03/2023       No

# %%
import openpyxl

filepath = r"https://github.com/data-to-insight/ERN-sessions/raw/main/data/small%20excel.xlsx"

df_dict = pd.read_excel(filepath, sheet_name=None)

df_dict['Child Data']
# Out:
#   ChildID Sex        DOB EHCP issued
# 0     id1   M 2014-12-05           N
# 1     id6   m 2016-01-06           n
# 2     id4   m 2013-11-09           Y
# 3     id3   F 2022-12-24           Y
# 4     id5   F 2020-01-15         NaN
# 5     id7   f 2022-09-17           y

# %%
df = pd.merge(df_dict['Child Data'], df_dict['Child extras'], how="left", on="ChildID")
df = pd.merge(df, df_dict['Sheet3'], how='left', on='Assessment Code')

# %%
condition = child_identifiers['Age']>5
over_5=child_identifiers[condition]
over_5

# %%
condition1= child_identifiers['GenderCurrent']==1
Gender1=child_identifiers[condition1]
Gender1
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0             0  RND000215205141  A850728973744        NaN         NaN
# 2             2  RND000750143123  A929946861554        NaN         NaN
# 10           10  RND000003988611  A512600833840        NaN         NaN
# 15           15  RND000616439909  A223285848317        NaN         NaN
# 19           19  RND000958425881  A882839253037        NaN         NaN
# ..          ...              ...            ...        ...         ...
# 305         305  RND000804026703  A725850113915        NaN         NaN
# 307         307  RND000288559211  A759430892355        NaN         NaN
# 311         311  RND000605823944  A978875208720        NaN         NaN
# 323         323  RND000044483554  A573619095658        NaN         NaN
# 324         324  RND000110305262  A921047772424        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# 0        2019-12-06                     NaN              1             NaN
# 2        2017-06-06              2019-12-06              1             NaN
# 10       2022-05-11                     NaN              1             NaN
# 15       2020-04-06                     NaN              1             NaN
# 19       2007-07-04                     NaN              1      2006-07-04
# ..              ...                     ...            ...             ...
# 305      2011-06-03                     NaN              1             NaN
# 307      2021-10-23                     NaN              1             NaN
# 311      2018-10-07                     NaN              1             NaN
# 323      2020-06-16                     NaN              1             NaN
# 324      2022-06-13              2011-06-03              1             NaN
#
# [78 rows x 9 columns]

# %%
condition3=child_identifiers['Age']>child_identifiers['Age'].mean()
over_mean=child_identifiers[condition3]
over_mean

# %%
child_identifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.5+ KB

# %%
merged_child_table=df
merged_child_table
# Out:
#      Unnamed: 0_x        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0               0  RND000215205141  A850728973744        NaN         NaN
# 1               1  RND000824303014  A141396438491        NaN         NaN
# 2               2  RND000750143123  A929946861554        NaN         NaN
# 3               3  RND000909164501  A612330267292        NaN         NaN
# 4               4  RND000382171815  A604459366806        NaN         NaN
# ..            ...              ...            ...        ...         ...
# 327           327  RND000112711501  A465246916125        NaN         NaN
# 328           328  RND000513120794  A540014111973        NaN         NaN
# 329           329  RND000541643134  A549582689058        NaN         NaN
# 330           330  RND000404939452  A889492349196        NaN         NaN
# 331           331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate  \
# 0        2019-12-06                     NaN              1             NaN
# 1        2011-04-27                     NaN              9             NaN
# 2        2017-06-06              2019-12-06              1             NaN
# 3        2014-10-03                     NaN              0             NaN
# 4        2019-09-25                     NaN              2             NaN
# ..              ...                     ...            ...             ...
# 327      2010-07-07                     NaN              2             NaN
# 328      2018-08-14                     NaN              2             NaN
# 329      2021-12-09                     NaN             51             NaN
# 330      2013-07-23                     NaN              2             NaN
# 331      2021-10-25                     NaN              9             NaN
#
#      Unnamed: 0_y Ethnicity
# 0               0      WIRT
# 1               1      WROM
# 2               2      AOTH
# 3               3      MWBC
# 4               4      APKN
# ..            ...       ...
# 327           327      WOTH
# 328           328      WROM
# 329           329      BCRB
# 330           330      AIND
# 331           331      WBRI
#
# [332 rows x 11 columns]

# %%
wrom_or_1 = merged_child_table[(merged_child_table['GenderCurrent'] == 1) | (merged_child_table['Ethnicity'] == 'WROM')]
wrom_or_1
# Out:
#      Unnamed: 0_x        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0               0  RND000215205141  A850728973744        NaN         NaN
# 1               1  RND000824303014  A141396438491        NaN         NaN
# 2               2  RND000750143123  A929946861554        NaN         NaN
# 10             10  RND000003988611  A512600833840        NaN         NaN
# 15             15  RND000616439909  A223285848317        NaN         NaN
# ..            ...              ...            ...        ...         ...
# 311           311  RND000605823944  A978875208720        NaN         NaN
# 314           314  RND000025120001  A469895090633        NaN         NaN
# 323           323  RND000044483554  A573619095658        NaN         NaN
# 324           324  RND000110305262  A921047772424        NaN         NaN
# 328           328  RND000513120794  A540014111973        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate  \
# 0        2019-12-06                     NaN              1             NaN
# 1        2011-04-27                     NaN              9             NaN
# 2        2017-06-06              2019-12-06              1             NaN
# 10       2022-05-11                     NaN              1             NaN
# 15       2020-04-06                     NaN              1             NaN
# ..              ...                     ...            ...             ...
# 311      2018-10-07                     NaN              1             NaN
# 314      2007-12-14                     NaN              0             NaN
# 323      2020-06-16                     NaN              1             NaN
# 324      2022-06-13              2011-06-03              1             NaN
# 328      2018-08-14                     NaN              2             NaN
#
#      Unnamed: 0_y Ethnicity
# 0               0      WIRT
# 1               1      WROM
# 2               2      AOTH
# 10             10      REFU
# 15             15      MWBC
# ..            ...       ...
# 311           311      NOBT
# 314           314      WROM
# 323           323      REFU
# 324           324      REFU
# 328           328      WROM
#
# [90 rows x 11 columns]
